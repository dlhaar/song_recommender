# %%
import pandas as pd

# %%
not_hot = pd.read_csv('tracks_features.csv')

# %%
not_hot = not_hot.sample(3000, random_state = 5)

# %%
not_hot.head()
# Out:
#                              id                          name  \
# 1113804  5LkGGy7JvhnDZWEk7xuqP4                  Bihotz urdin
# 900506   4oYoZUGOMIOjxefJ0VLuHQ                 Race to Space
# 683529   3T7PUoQjtSD5KO2MIwoMrk  Local Mix-Up / Murder Charge
# 1165453  7IDr1U2i7qqai1FsZEdlwf  Stars Fell in Alabama - Live
# 830113   5pzJv7wxk9DcV4qRmoiTqR           The House I Live In
#
#                                    album                album_id  \
# 1113804                          16 Lore  1SAOLgXqL5peWuoyORMEwa
# 900506                               Dog  00ZJDh0xx4S92uZjZtQYLn
# 683529    Same Place The Fly Got Smashed  34GHEHF9oNZr54nCYvDhGu
# 1165453  The Art of the Piano Duo (Live)  55TE4mtiBkGAqqcCvm4hSv
# 830113   Sinatra Sings His Greatest Hits  57vPH8jXw3PF0zD6zeaNOD
#
#                                     artists  \
# 1113804                            ['Gari']
# 900506                              ['DoG']
# 683529                 ['Guided By Voices']
# ...

# %%
not_hot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, 1113804 to 785724
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                3000 non-null   object
#  1   name              3000 non-null   object
#  2   album             3000 non-null   object
#  3   album_id          3000 non-null   object
#  4   artists           3000 non-null   object
#  5   artist_ids        3000 non-null   object
#  6   track_number      3000 non-null   int64
#  7   disc_number       3000 non-null   int64
#  8   explicit          3000 non-null   bool
#  9   danceability      3000 non-null   float64
#  10  energy            3000 non-null   float64
#  11  key               3000 non-null   int64
#  12  loudness          3000 non-null   float64
#  13  mode              3000 non-null   int64
#  14  speechiness       3000 non-null   float64
#  15  acousticness      3000 non-null   float64
# ...

# %%
not_hot = not_hot[['id', 'name', 'artists', 'danceability', 'energy', 'acousticness', 'instrumentalness', 'tempo']]

# %%
not_hot.shape
# Out:
# (3000, 8)

# %%
not_hot['artists'] = not_hot['artists'].str.replace('[', '').str.replace(']', '').str.replace(',', ' and ').str.replace("'", "")

# %%
not_hot.head()
# Out:
#                              id                          name  \
# 1113804  5LkGGy7JvhnDZWEk7xuqP4                  Bihotz urdin
# 900506   4oYoZUGOMIOjxefJ0VLuHQ                 Race to Space
# 683529   3T7PUoQjtSD5KO2MIwoMrk  Local Mix-Up / Murder Charge
# 1165453  7IDr1U2i7qqai1FsZEdlwf  Stars Fell in Alabama - Live
# 830113   5pzJv7wxk9DcV4qRmoiTqR           The House I Live In
#
#                                   artists  danceability  energy  acousticness  \
# 1113804                              Gari         0.495   0.469         0.768
# 900506                                DoG         0.383   0.450         0.390
# 683529                   Guided By Voices         0.232   0.459         0.392
# 1165453  Kenny Barron and  Mulgrew Miller         0.484   0.335         0.993
# 830113                      Frank Sinatra         0.241   0.131         0.964
#
#          instrumentalness    tempo
# 1113804           0.00000  145.873
# 900506            0.36800  156.238
# ...

# %%
not_hot.duplicated().sum()
# Out:
# 0

# %%
not_hot = not_hot.rename(columns={'name':'titles'})
not_hot.head()
# Out:
#                              id                        titles  \
# 1113804  5LkGGy7JvhnDZWEk7xuqP4                  Bihotz urdin
# 900506   4oYoZUGOMIOjxefJ0VLuHQ                 Race to Space
# 683529   3T7PUoQjtSD5KO2MIwoMrk  Local Mix-Up / Murder Charge
# 1165453  7IDr1U2i7qqai1FsZEdlwf  Stars Fell in Alabama - Live
# 830113   5pzJv7wxk9DcV4qRmoiTqR           The House I Live In
#
#                                   artists  danceability  energy  acousticness  \
# 1113804                              Gari         0.495   0.469         0.768
# 900506                                DoG         0.383   0.450         0.390
# 683529                   Guided By Voices         0.232   0.459         0.392
# 1165453  Kenny Barron and  Mulgrew Miller         0.484   0.335         0.993
# 830113                      Frank Sinatra         0.241   0.131         0.964
#
#          instrumentalness    tempo
# 1113804           0.00000  145.873
# 900506            0.36800  156.238
# ...

# %%
#hot = pd.read_csv('../lab-web-scraping-single-page/popular.csv')

# %%
hot.head()
# Out:
#        titles              artists
# 0     Vampire       Olivia Rodrigo
# 1  Last Night        Morgan Wallen
# 2    Fast Car           Luke Combs
# 3   Calm Down  Rema & Selena Gomez
# 4     Flowers          Miley Cyrus

# %%
inner_join = not_hot.merge(hot, how = 'inner', on = ['titles', 'artists'])

# %%
inner_join.shape
# Out:
# (0, 2)

# %%
inner_join
# Out:
# Empty DataFrame
# Columns: [artists, titles]
# Index: []

# %%
not_hot.to_csv('not_hot.csv', index = False)
